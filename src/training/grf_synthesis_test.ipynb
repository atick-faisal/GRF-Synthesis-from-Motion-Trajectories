# %% [markdown]
# <a href="https://colab.research.google.com/github/atick-faisal/GRF-Synthesis-from-Motion-Trajectories/blob/main/src/training/grf_synthesis_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install --upgrade pandas==1.3.4

# %% [markdown]
# # Download and prepare data

# %%
# !gdown --id "1kNGwWBQp6kmAioLP-_zWx7r42SzoEO3v"
# !unzip -u UNet.zip

## DB1 Normal Velocity
# !gdown --id "16_ACUGzahIkaEYXkKZ2DJ_IlPpXgxkeg"

## DB2
# !gdown --id "1-0-jQ_yS6ojnosNeEYpy8f5tnpYLAd5b"

# # DB2 High vel
# !gdown --id "1LRwmMUFF1Vdxlsj2mqqkVvhCLTCIr8F4"

# %% [markdown]
# # Import libraries

# %%
import h5py
import scipy
import random
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import scipy.io as sio
import matplotlib.pyplot as plt

from tqdm import tqdm
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error, median_absolute_error, mean_absolute_error
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from tensorflow import keras
from tensorflow.python.keras import backend as K
from tensorflow.python.ops import array_ops
from tensorflow.python.ops import math_ops

from UNet_1DCNN import UNet
from FPN_1DCNN import FPN
from AlbuNet_1DCNN import AlbUNet

# %matplotlib inline
sns.set(font_scale=1.5)
sns.set_style("darkgrid", {'font.family':'serif', 'font.serif':'Times New Roman'})

models_dir = '/content/drive/MyDrive/Research/GRF Data Synthesis/Results/DB2/Moment/Models/Y/'
figures_dir = '/content/drive/MyDrive/Research/GRF Data Synthesis/Results/DB2/Moment/Figures/Y/'

# %% [markdown]
# # Corr-Coef Loss

# %%
from keras import backend as K
def correlation_coefficient_loss(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x)
    my = K.mean(y)
    xm, ym = x-mx, y-my
    r_num = K.sum(tf.multiply(xm,ym))
    r_den = K.sqrt(tf.multiply(K.sum(K.square(xm)), K.sum(K.square(ym))))
    r = r_num / r_den

    mae = tf.keras.losses.MeanAbsoluteError()
    error = mae(y_true, y_pred)
    r = K.maximum(K.minimum(r, 1.0), -1.0)
    
    return (1 - r) * error

# %% [markdown]
# # Train test split

# %%
data = joblib.load('/content/data2_f15_t6_n1_high_vel_combined.joblib')
X_Train = data['train_X']
X_Test = data['test_X']
Y_Train = data['train_y']
Y_Test = data['test_y']

print(X_Train.shape)
print(X_Test.shape)
print(Y_Train.shape)
print(Y_Test.shape)
# Out:
# (1315, 1024, 15)
# (329, 1024, 15)
# (1315, 1024, 6)
# (329, 1024, 6)

# %% [markdown]
# # Axis Selection

# %%
# X_Train = X_Train[:, :, [10, 11, 12, 13, 14]]
# X_Test = X_Test[:, :, [10, 11, 12, 13, 14]]
Y_Train = Y_Train[:, :, 0]
Y_Test = Y_Test[:, :, 0]

X_Train = np.nan_to_num(X_Train)
X_Test = np.nan_to_num(X_Test)
Y_Train = np.nan_to_num(Y_Train)
Y_Test = np.nan_to_num(Y_Test)

print(X_Train.shape)
print(X_Test.shape)
print(Y_Train.shape)
print(Y_Test.shape)
# Out:
# (1315, 1024, 15)
# (329, 1024, 15)
# (1315, 1024)
# (329, 1024)

# %%
plt.plot(X_Test[:, :, 1].T)
plt.show()

# %%
Y_Train.shape
# Out:
# (1315, 1024)

# %%
plt.plot(Y_Test.T)
plt.show()

# %%
FRAME_LEN = X_Train.shape[1]
N_CHANNELS = X_Train.shape[2]

# %% [markdown]
# # Configuration

# %%
model_name = 'MultiResUNet' # UNet or UNetPP
signal_length = FRAME_LEN # Length of each Segment
model_depth = 5 # Number of Level in the CNN Model
model_width = 16 # Width of the Initial Layer, subsequent layers start from here
kernel_size = 9 # Size of the Kernels/Filter
num_channel = N_CHANNELS # Number of Channels in the Model
D_S = 0 # Turn on Deep Supervision
A_E = 0 # Turn on AutoEncoder Mode for Feature Extraction
A_G = 0 # Attention Guided
problem_type = 'Regression'
output_nums = 1 # Number of Class for Classification Problems, always '1' for Regression Problems
'''Only required if the AutoEncoder Mode is turned on'''
feature_number = 1024 # Number of Features to be Extracted
'''Only required for MultiResUNet'''
alpha = 1 # Model Width Expansion Parameter

# %% [markdown]
# # Prepare for deep supervision

# %%
def prepareTrainDict(y, model_depth, signal_length, model_name):
  def approximate(inp, w_len, signal_length):
    op = np.zeros((len(inp),signal_length//w_len))
    for i in range(0,signal_length,w_len):
      try:
        op[:,i//w_len] = np.mean(inp[:,i:i+w_len],axis=1)
      except Exception as e:
        print(e)
        print(i)
  	
    return op

  out = {}
  Y_Train_dict = {}
  out['out'] = np.array(y)
  Y_Train_dict['out'] = out['out']
  for i in range(1, (model_depth+1)):
    name = f'level{i}'
    if ((model_name == 'UNet') or (model_name == 'MultiResUNet') or (model_name == 'FPN')):
      out[name] = np.expand_dims(approximate(np.squeeze(y), 2**i, signal_length),axis = 2)
    elif ((model_name == 'UNetE') or (model_name == 'UNetP') or (model_name == 'UNetPP')):
      out[name] = np.expand_dims(approximate(np.squeeze(y), 2**0, signal_length),axis = 2)
    Y_Train_dict[f'level{i}'] = out[f'level{i}']
  
  return out, Y_Train_dict

# %%
X_Train1 = X_Train
X_Test1 = X_Test
[Y_Train1, Y_Train_dict] = prepareTrainDict(Y_Train, model_depth, signal_length, model_name)
[Y_Test1, Y_Test_dict] = prepareTrainDict(Y_Test, model_depth, signal_length, model_name)

# %%
loss_weights = np.zeros(model_depth)

for i in range(0, model_depth):
   loss_weights[i] = 1-(i*0.1)
   
loss_weights
# Out:
# array([1. , 0.9, 0.8, 0.7, 0.6])

# %% [markdown]
# # Build and compile model

# %%
optimizer = tf.keras.optimizers.Adam(
    learning_rate = 0.001
)

if D_S == 0:
    # Build model for EEG Motion Artifact Removal - Deep Unet Architecture
    # AutoEncoder should be set at 'FALSE' for the Deep U-net model for Signal Reconstruction
    # D_S = 0, A_E = 0
    model = UNet(
        signal_length,
        model_depth,
        num_channel, 
        model_width, 
        kernel_size, 
        problem_type=problem_type, 
        output_nums=output_nums, 
        ds=D_S,
        ae=A_E, 
        ag=A_G,
        alpha=alpha
    ).UNet()

    model.compile(
        loss= 'mean_absolute_error', 
        optimizer= optimizer, 
        metrics= ['mean_squared_error','accuracy']
    )
    #
elif D_S == 1:
    # Build model for EEG Motion Artifact Removal - Deep Unet Architecture
    # AutoEncoder should be set at 'FALSE' for the Deep U-net model for Signal Reconstruction
    # D_S = 1, A_E = 0
    model = UNet(
        signal_length, model_depth, 
        num_channel, 
        model_width, 
        kernel_size, 
        problem_type=problem_type, 
        output_nums=output_nums, 
        ds=D_S,
        ae=A_E,
        ag=A_G, 
        alpha=alpha
    ).MultiResUNet()

    model.compile(
        loss= 'mean_absolute_error', 
        optimizer= optimizer, 
        metrics= ['mean_squared_error'], 
        loss_weights= loss_weights
    )

# %% [markdown]
# # Training

# %%
config = model_name + '_moment_' + str(signal_length) + '_' \
            + str(N_CHANNELS) + '_' + str(model_width) +'_' \
            + str(model_depth) + '_' + str(num_channel) + '_normal_vel_' \
            + str(D_S) + str(A_G) + '_axis_corrected'

# %%
if D_S == 0:
    callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30, mode='min'), 
        tf.keras.callbacks.ModelCheckpoint(
            'trained_models/' + config +'.h5', 
                verbose=1, 
                monitor='val_loss', 
                save_best_only=True, 
                mode='min'
        )
    ]
    history = model.fit(
        X_Train, Y_Train, 
        epochs=300, 
        batch_size=64, 
        verbose=1, 
        validation_split=0.2, 
        shuffle=True, 
        callbacks=callbacks
    )
    
elif D_S == 1:
    callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_out_loss', patience=30, mode='min'), 
        tf.keras.callbacks.ModelCheckpoint(
            'trained_models/' + config + '.h5', 
                verbose=1, 
                monitor='val_loss', 
                save_best_only=True, 
                mode='min'
        )
    ]
    history = model.fit(
        X_Train1, 
        Y_Train_dict, 
        epochs=300, 
        batch_size=64, 
        verbose=1, 
        validation_split=0.2, 
        shuffle=True, 
        callbacks=callbacks
    )
# Out:
# Epoch 1/300
# 17/17 [==============================] - ETA: 0s - loss: 0.5499 - mean_squared_error: 0.7139 - accuracy: 0.0012
# Epoch 00001: val_loss improved from inf to 0.51990, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 17s 352ms/step - loss: 0.5499 - mean_squared_error: 0.7139 - accuracy: 0.0012 - val_loss: 0.5199 - val_mean_squared_error: 0.3252 - val_accuracy: 9.7656e-04
# Epoch 2/300
# 17/17 [==============================] - ETA: 0s - loss: 0.1540 - mean_squared_error: 0.0710 - accuracy: 0.0018
# Epoch 00002: val_loss improved from 0.51990 to 0.44459, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 240ms/step - loss: 0.1540 - mean_squared_error: 0.0710 - accuracy: 0.0018 - val_loss: 0.4446 - val_mean_squared_error: 0.2418 - val_accuracy: 9.7656e-04
# Epoch 3/300
# 17/17 [==============================] - ETA: 0s - loss: 0.1009 - mean_squared_error: 0.0180 - accuracy: 0.0019
# Epoch 00003: val_loss improved from 0.44459 to 0.37323, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 240ms/step - loss: 0.1009 - mean_squared_error: 0.0180 - accuracy: 0.0019 - val_loss: 0.3732 - val_mean_squared_error: 0.1710 - val_accuracy: 9.7656e-04
# Epoch 4/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0924 - mean_squared_error: 0.0145 - accuracy: 0.0019
# Epoch 00004: val_loss improved from 0.37323 to 0.30914, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 240ms/step - loss: 0.0924 - mean_squared_error: 0.0145 - accuracy: 0.0019 - val_loss: 0.3091 - val_mean_squared_error: 0.1188 - val_accuracy: 0.0012
# Epoch 5/300
# 17/17 [==============================] - ETA: 0s - loss: 0.
300
# 17/17 [==============================] - ETA: 0s - loss: 0.0696 - mean_squared_error: 0.0083 - accuracy: 0.0020
# Epoch 00025: val_loss did not improve from 0.08704
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0696 - mean_squared_error: 0.0083 - accuracy: 0.0020 - val_loss: 0.1103 - val_mean_squared_error: 0.0204 - val_accuracy: 0.0019
# Epoch 26/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0708 - mean_squared_error: 0.0086 - accuracy: 0.0020
# Epoch 00026: val_loss did not improve from 0.08704
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0708 - mean_squared_error: 0.0086 - accuracy: 0.0020 - val_loss: 0.1035 - val_mean_squared_error: 0.0205 - val_accuracy: 0.0019
# Epoch 27/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0686 - mean_squared_error: 0.0080 - accuracy: 0.0020
# Epoch 00027: val_loss did not improve from 0.08704
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0686 - mean_squared_error: 0.0080 - accuracy: 0.0020 - val_loss: 0.0910 - val_mean_squared_error: 0.0137 - val_accuracy: 0.0020
# Epoch 28/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0679 - mean_squared_error: 0.0079 - accuracy: 0.0020
# Epoch 00028: val_loss did not improve from 0.08704
# 17/17 [==============================] - 3s 201ms/step - loss: 0.0679 - mean_squared_error: 0.0079 - accuracy: 0.0020 - val_loss: 0.0982 - val_mean_squared_error: 0.0174 - val_accuracy: 0.0019
# Epoch 29/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0676 - mean_squared_error: 0.0079 - accuracy: 0.0020
# Epoch 00029: val_loss improved from 0.08704 to 0.08324, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 242ms/step - loss: 0.0676 - mean_squared_error: 0.0079 - accuracy: 0.0020 - val_loss: 0.0832 - val_mean_squared_error: 0.0121 - val_accuracy: 0.0019
# Epoch 30/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0682 - mean_squared_error: 0.0080 - accuracy: 0.0020
# Epoch 00030: val_loss did not improve from 0.08324
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0682 - mean_squared_error: 0.0080 - accuracy: 0.0020 - val_loss: 0.0948 - val_mean_squared_error: 0.0150 - val_accuracy: 0.0019
# Epoch 31/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0666 - mean_squared_error: 0.0076 - accuracy: 0.0020
# Epoch 00031: val_loss did not improve from 0.08324
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0666 - mean_squared_error: 0.0076 - accuracy: 0.0020 - val_loss: 0.0950 - val_mean_squared_error: 0.0149 - val_accuracy: 0.0019
# Epoch 32/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0665 - mean_squared_error: 0.0075 - accuracy: 0.0020
# Epoch 00032: val_loss did not improve from 0.08324
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0665 - mean_squared_error: 0.0075 - accuracy: 0.0020 - val_loss: 0.1017 - val_mean_squared_error: 0.0190 - val_accuracy: 0.0019
# Epoch 33/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0657 - mean_squared_error: 0.0074 - accuracy: 0.0020
# Epoch 00033: val_loss did not improve from 0.08324
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0657 - mean_squared_error: 0.0074 - accuracy: 0.0020 - val_loss: 0.0986 - val_mean_squared_error: 0.0165 - val_accuracy: 0.0020
# Epoch 34/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0655 - mean_squared_error: 0.0074 - accuracy: 0.0020
# Epoch 00034: val_loss did not improve from 0.08324
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0655 - mean_squared_error: 0.0074 - accuracy: 0.0020 - val_loss: 0.0866 - val_mean_squared_error: 0.0137 - val_accuracy: 0.0019
# Epoch 35/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0650 - mean_squared_error: 0.0072 - accuracy: 0.0020
# Epoch 00035: val_loss improved from 0.08324 to 0.08024, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s
300
# 17/17 [==============================] - ETA: 0s - loss: 0.0604 - mean_squared_error: 0.0064 - accuracy: 0.0020
# Epoch 00046: val_loss improved from 0.08004 to 0.07761, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 248ms/step - loss: 0.0604 - mean_squared_error: 0.0064 - accuracy: 0.0020 - val_loss: 0.0776 - val_mean_squared_error: 0.0103 - val_accuracy: 0.0020
# Epoch 47/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0609 - mean_squared_error: 0.0065 - accuracy: 0.0020
# Epoch 00047: val_loss improved from 0.07761 to 0.07320, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 242ms/step - loss: 0.0609 - mean_squared_error: 0.0065 - accuracy: 0.0020 - val_loss: 0.0732 - val_mean_squared_error: 0.0092 - val_accuracy: 0.0020
# Epoch 48/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0601 - mean_squared_error: 0.0063 - accuracy: 0.0020
# Epoch 00048: val_loss did not improve from 0.07320
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0601 - mean_squared_error: 0.0063 - accuracy: 0.0020 - val_loss: 0.0778 - val_mean_squared_error: 0.0106 - val_accuracy: 0.0019
# Epoch 49/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0604 - mean_squared_error: 0.0064 - accuracy: 0.0020
# Epoch 00049: val_loss did not improve from 0.07320
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0604 - mean_squared_error: 0.0064 - accuracy: 0.0020 - val_loss: 0.0745 - val_mean_squared_error: 0.0095 - val_accuracy: 0.0020
# Epoch 50/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0584 - mean_squared_error: 0.0060 - accuracy: 0.0020
# Epoch 00050: val_loss improved from 0.07320 to 0.07254, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 242ms/step - loss: 0.0584 - mean_squared_error: 0.0060 - accuracy: 0.0020 - val_loss: 0.0725 - val_mean_squared_error: 0.0090 - val_accuracy: 0.0020
# Epoch 51/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0578 - mean_squared_error: 0.0059 - accuracy: 0.0020
# Epoch 00051: val_loss did not improve from 0.07254
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0578 - mean_squared_error: 0.0059 - accuracy: 0.0020 - val_loss: 0.0758 - val_mean_squared_error: 0.0097 - val_accuracy: 0.0019
# Epoch 52/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0594 - mean_squared_error: 0.0062 - accuracy: 0.0020
# Epoch 00052: val_loss did not improve from 0.07254
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0594 - mean_squared_error: 0.0062 - accuracy: 0.0020 - val_loss: 0.0817 - val_mean_squared_error: 0.0113 - val_accuracy: 0.0020
# Epoch 53/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0578 - mean_squared_error: 0.0059 - accuracy: 0.0020
# Epoch 00053: val_loss did not improve from 0.07254
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0578 - mean_squared_error: 0.0059 - accuracy: 0.0020 - val_loss: 0.0769 - val_mean_squared_error: 0.0101 - val_accuracy: 0.0020
# Epoch 54/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0579 - mean_squared_error: 0.0059 - accuracy: 0.0020
# Epoch 00054: val_loss did not improve from 0.07254
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0579 - mean_squared_error: 0.0059 - accuracy: 0.0020 - val_loss: 0.0761 - val_mean_squared_error: 0.0104 - val_accuracy: 0.0019
# Epoch 55/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0598 - mean_squared_error: 0.0063 - accuracy: 0.0020
# Epoch 00055: val_loss did not improve from 0.07254
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0598 - mean_squared_error: 0.0063 - accuracy: 0.0020 - val_loss: 0.0773 - val_mean_squared_error: 0.0099 - val_accuracy: 0.0020
# Epoch 56/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0571 - mean_squared_error: 0.0057 - accuracy: 0.0020
# Epoch 00056: val_loss did not improve from 0.07254
# 17/17 [==============================] - 4s 208ms/step - loss: 0.0571 - mean_squared_error: 0.0057 - accuracy: 0.0020 - val_loss: 0.0764 - val_mean_squared_error: 0.0099 - val_accuracy: 0.0020
# Epoch 57/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0567 - mean_squared_error: 0.0058 - accuracy: 0.0020
# Epoch 00057: val_loss did not improve from 0.07254
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0567 - mean_squared_error: 0.0058 - accuracy: 0.0020 - val_loss: 0.0749 - val_mean_squared_error: 0.0096 - val_accuracy: 0.0019
# Epoch 58/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0550 - mean_squared_error: 0.0054 - accuracy: 0.0020
# Epoch 00058: val_loss did not improve from 0.07254
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0550 - mean_squared_error: 0.0054 - accuracy: 0.0020 - val_loss: 0.0751 - val_mean_squared_error: 0.0098 - val_accuracy: 0.0019
# Epoch 59/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0556 - mean_squared_error: 0.0055 - accuracy: 0.0020
# Epoch 00059: val_loss improved from 0.07254 to 0.06849, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 244ms/step - loss: 0.0556 - mean_squared_error: 0.0055 - accuracy: 0.0020 - val_loss: 0.0685 - val_mean_squared_error: 0.0081 - val_accuracy: 0.0020
# Epoch 60/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0549 - mean_squared_error: 0.0054 - accuracy: 0.0020
# Epoch 00060: val_loss did not improve from 0.06849
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0549 - mean_squared_error: 0.0054 - accuracy: 0.0020 - val_loss: 0.0733 - val_mean_squared_error: 0.0092 - val_accuracy: 0.0020
# Epoch 61/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0553 - mean_squared_error: 0.0054 - accuracy: 0.0020
# Epoch 00061: val_loss did not improve from 0.06849
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0553 - mean_squared_error: 0.0054 - accuracy: 0.0020 - val_loss: 0.0722 - val_mean_squared_error: 0.0092 - val_accuracy: 0.0019
# Epoch 62/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0554 - mean_squared_error: 0.0055 - accuracy: 0.0020
# Epoch 00062: val_loss did not improve from 0.06849
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0554 - mean_squared_error: 0.0055 - accuracy: 0.0020 - val_loss: 0.0745 - val_mean_squared_error: 0.0100 - val_accuracy: 0.0020
# Epoch 63/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0547 - mean_squared_error: 0.0053 - accuracy: 0.0020
# Epoch 00063: val_loss did not improve from 0.06849
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0547 - mean_squared_error: 0.0053 - accuracy: 0.0020 - val_loss: 0.0728 - val_mean_squared_error: 0.0092 - val_accuracy: 0.0020
# Epoch 64/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0544 - mean_squared_error: 0.0053 - accuracy: 0.0020
# Epoch 00064: val_loss did not improve from 0.06849
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0544 - mean_squared_error: 0.0053 - accuracy: 0.0020 - val_loss: 0.0744 - val_mean_squared_error: 0.0095 - val_accuracy: 0.0019
# Epoch 65/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0537 - mean_squared_error: 0.0052 - accuracy: 0.0020
# Epoch 00065: val_loss did not improve from 0.06849
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0537 - mean_squared_error: 0.0052 - accuracy: 0.0020 - val_loss: 0.0718 - val_mean_squared_error: 0.0089 - val_accuracy: 0.0020
# Epoch 66/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0542 - mean_squared_error: 0.0052 - accuracy: 0.0020
# Epoch 00066: val_loss did not improve from 0.06849
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0542 - mean_squared_error: 0.0052 - accuracy: 0.0020 - val_loss: 0.0815 - val_mean_squared_error: 0.0115 - val_accuracy: 0.0020
# Epoch 67/300
# 17/17 [==============================] - ETA: 0s - loss: 0.
val_loss did not improve from 0.06836
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0513 - mean_squared_error: 0.0047 - accuracy: 0.0020 - val_loss: 0.1537 - val_mean_squared_error: 0.0821 - val_accuracy: 0.0018
# Epoch 92/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0513 - mean_squared_error: 0.0048 - accuracy: 0.0020
# Epoch 00092: val_loss did not improve from 0.06836
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0513 - mean_squared_error: 0.0048 - accuracy: 0.0020 - val_loss: 0.0889 - val_mean_squared_error: 0.0185 - val_accuracy: 0.0019
# Epoch 93/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0478 - mean_squared_error: 0.0042 - accuracy: 0.0020
# Epoch 00093: val_loss did not improve from 0.06836
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0478 - mean_squared_error: 0.0042 - accuracy: 0.0020 - val_loss: 0.0748 - val_mean_squared_error: 0.0108 - val_accuracy: 0.0019
# Epoch 94/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0473 - mean_squared_error: 0.0041 - accuracy: 0.0020
# Epoch 00094: val_loss did not improve from 0.06836
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0473 - mean_squared_error: 0.0041 - accuracy: 0.0020 - val_loss: 0.0745 - val_mean_squared_error: 0.0097 - val_accuracy: 0.0020
# Epoch 95/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0466 - mean_squared_error: 0.0040 - accuracy: 0.0020
# Epoch 00095: val_loss did not improve from 0.06836
# 17/17 [==============================] - 4s 209ms/step - loss: 0.0466 - mean_squared_error: 0.0040 - accuracy: 0.0020 - val_loss: 0.0690 - val_mean_squared_error: 0.0081 - val_accuracy: 0.0020
# Epoch 96/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0460 - mean_squared_error: 0.0038 - accuracy: 0.0020
# Epoch 00096: val_loss did not improve from 0.06836
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0460 - mean_squared_error: 0.0038 - accuracy: 0.0020 - val_loss: 0.0688 - val_mean_squared_error: 0.0082 - val_accuracy: 0.0020
# Epoch 97/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0453 - mean_squared_error: 0.0037 - accuracy: 0.0020
# Epoch 00097: val_loss improved from 0.06836 to 0.06828, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 245ms/step - loss: 0.0453 - mean_squared_error: 0.0037 - accuracy: 0.0020 - val_loss: 0.0683 - val_mean_squared_error: 0.0080 - val_accuracy: 0.0020
# Epoch 98/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0441 - mean_squared_error: 0.0036 - accuracy: 0.0020
# Epoch 00098: val_loss did not improve from 0.06828
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0441 - mean_squared_error: 0.0036 - accuracy: 0.0020 - val_loss: 0.0713 - val_mean_squared_error: 0.0087 - val_accuracy: 0.0019
# Epoch 99/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0468 - mean_squared_error: 0.0040 - accuracy: 0.0020
# Epoch 00099: val_loss did not improve from 0.06828
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0468 - mean_squared_error: 0.0040 - accuracy: 0.0020 - val_loss: 0.0707 - val_mean_squared_error: 0.0086 - val_accuracy: 0.0020
# Epoch 100/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0441 - mean_squared_error: 0.0036 - accuracy: 0.0020
# Epoch 00100: val_loss did not improve from 0.06828
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0441 - mean_squared_error: 0.0036 - accuracy: 0.0020 - val_loss: 0.0732 - val_mean_squared_error: 0.0090 - val_accuracy: 0.0020
# Epoch 101/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0436 - mean_squared_error: 0.0034 - accuracy: 0.0020
# Epoch 00101: val_loss did not improve from 0.06828
# 17/17 [==============================] - 3s 202ms/step - loss: 0.0436 - mean_squared_error: 0.0034 - accuracy: 0.0020 - val_loss: 0.0743 - val_mean_squared_error: 0.0094 - val_accuracy: 0.0020
# Epoch 102/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0417 - mean_squared_error: 0.0032 - accuracy: 0.0020
# Epoch 00102: val_loss improved from 0.06828 to 0.06790, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s
300
# 17/17 [==============================] - ETA: 0s - loss: 0.0403 - mean_squared_error: 0.0030 - accuracy: 0.0020
# Epoch 00115: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0403 - mean_squared_error: 0.0030 - accuracy: 0.0020 - val_loss: 0.0701 - val_mean_squared_error: 0.0085 - val_accuracy: 0.0020
# Epoch 116/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0411 - mean_squared_error: 0.0031 - accuracy: 0.0020
# Epoch 00116: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0411 - mean_squared_error: 0.0031 - accuracy: 0.0020 - val_loss: 0.0739 - val_mean_squared_error: 0.0093 - val_accuracy: 0.0020
# Epoch 117/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0388 - mean_squared_error: 0.0028 - accuracy: 0.0020
# Epoch 00117: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0388 - mean_squared_error: 0.0028 - accuracy: 0.0020 - val_loss: 0.0717 - val_mean_squared_error: 0.0090 - val_accuracy: 0.0019
# Epoch 118/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0385 - mean_squared_error: 0.0027 - accuracy: 0.0020
# Epoch 00118: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0385 - mean_squared_error: 0.0027 - accuracy: 0.0020 - val_loss: 0.0681 - val_mean_squared_error: 0.0080 - val_accuracy: 0.0020
# Epoch 119/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0377 - mean_squared_error: 0.0026 - accuracy: 0.0020
# Epoch 00119: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0377 - mean_squared_error: 0.0026 - accuracy: 0.0020 - val_loss: 0.0741 - val_mean_squared_error: 0.0096 - val_accuracy: 0.0020
# Epoch 120/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0389 - mean_squared_error: 0.0028 - accuracy: 0.0020
# Epoch 00120: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0389 - mean_squared_error: 0.0028 - accuracy: 0.0020 - val_loss: 0.0690 - val_mean_squared_error: 0.0083 - val_accuracy: 0.0020
# Epoch 121/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0381 - mean_squared_error: 0.0026 - accuracy: 0.0020
# Epoch 00121: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0381 - mean_squared_error: 0.0026 - accuracy: 0.0020 - val_loss: 0.0718 - val_mean_squared_error: 0.0089 - val_accuracy: 0.0020
# Epoch 122/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0376 - mean_squared_error: 0.0026 - accuracy: 0.0020
# Epoch 00122: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0376 - mean_squared_error: 0.0026 - accuracy: 0.0020 - val_loss: 0.0695 - val_mean_squared_error: 0.0084 - val_accuracy: 0.0020
# Epoch 123/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0383 - mean_squared_error: 0.0027 - accuracy: 0.0020
# Epoch 00123: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0383 - mean_squared_error: 0.0027 - accuracy: 0.0020 - val_loss: 0.0707 - val_mean_squared_error: 0.0086 - val_accuracy: 0.0019
# Epoch 124/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0362 - mean_squared_error: 0.0024 - accuracy: 0.0020
# Epoch 00124: val_loss did not improve from 0.06790
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0362 - mean_squared_error: 0.0024 - accuracy: 0.0020 - val_loss: 0.0687 - val_mean_squared_error: 0.0081 - val_accuracy: 0.0020
# Epoch 125/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0360 - mean_squared_error: 0.0024 - accuracy: 0.0020
# Epoch 00125: val_loss improved from 0.06790 to 0.06675, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 246ms/step - loss: 0.0360 - mean_squared_error: 0.0024 - accuracy: 0.0020 - val_loss: 0.0668 - val_mean_squared_error: 0.0077 - val_accuracy: 0.0019
# Epoch 126/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0369 - mean_squared_error: 0.0025 - accuracy: 0.0020
# Epoch 00126: val_loss did not improve from 0.06675
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0369 - mean_squared_error: 0.0025 - accuracy: 0.0020 - val_loss: 0.0686 - val_mean_squared_error: 0.0081 - val_accuracy: 0.0019
# Epoch 127/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0351 - mean_squared_error: 0.0023 - accuracy: 0.0020
# Epoch 00127: val_loss did not improve from 0.06675
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0351 - mean_squared_error: 0.0023 - accuracy: 0.0020 - val_loss: 0.0709 - val_mean_squared_error: 0.0086 - val_accuracy: 0.0020
# Epoch 128/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0345 - mean_squared_error: 0.0022 - accuracy: 0.0020
# Epoch 00128: val_loss did not improve from 0.06675
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0345 - mean_squared_error: 0.0022 - accuracy: 0.0020 - val_loss: 0.0686 - val_mean_squared_error: 0.0082 - val_accuracy: 0.0020
# Epoch 129/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0348 - mean_squared_error: 0.0022 - accuracy: 0.0020
# Epoch 00129: val_loss did not improve from 0.06675
# 17/17 [==============================] - 4s 209ms/step - loss: 0.0348 - mean_squared_error: 0.0022 - accuracy: 0.0020 - val_loss: 0.0714 - val_mean_squared_error: 0.0088 - val_accuracy: 0.0019
# Epoch 130/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0341 - mean_squared_error: 0.0022 - accuracy: 0.0020
# Epoch 00130: val_loss did not improve from 0.06675
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0341 - mean_squared_error: 0.0022 - accuracy: 0.0020 - val_loss: 0.0691 - val_mean_squared_error: 0.0083 - val_accuracy: 0.0020
# Epoch 131/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0322 - mean_squared_error: 0.0019 - accuracy: 0.0020
# Epoch 00131: val_loss did not improve from 0.06675
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0322 - mean_squared_error: 0.0019 - accuracy: 0.0020 - val_loss: 0.0690 - val_mean_squared_error: 0.0082 - val_accuracy: 0.0020
# Epoch 132/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0326 - mean_squared_error: 0.0019 - accuracy: 0.0020
# Epoch 00132: val_loss did not improve from 0.06675
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0326 - mean_squared_error: 0.0019 - accuracy: 0.0020 - val_loss: 0.0709 - val_mean_squared_error: 0.0088 - val_accuracy: 0.0019
# Epoch 133/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0330 - mean_squared_error: 0.0021 - accuracy: 0.0020
# Epoch 00133: val_loss improved from 0.06675 to 0.06496, saving model to trained_models/MultiResUNet_moment_1024_15_16_5_15_normal_vel_00_axis_corrected.h5
# 17/17 [==============================] - 4s 247ms/step - loss: 0.0330 - mean_squared_error: 0.0021 - accuracy: 0.0020 - val_loss: 0.0650 - val_mean_squared_error: 0.0074 - val_accuracy: 0.0020
# Epoch 134/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0320 - mean_squared_error: 0.0019 - accuracy: 0.0020
# Epoch 00134: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 203ms/step - loss: 0.0320 - mean_squared_error: 0.0019 - accuracy: 0.0020 - val_loss: 0.0679 - val_mean_squared_error: 0.0080 - val_accuracy: 0.0020
# Epoch 135/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0344 - mean_squared_error: 0.0022 - accuracy: 0.0020
# Epoch 00135: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0344 - mean_squared_error: 0.0022 - accuracy: 0.0020 - val_loss: 0.0712 - val_mean_squared_error: 0.0088 - val_accuracy: 0.0020
# Epoch 136/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0320 - mean_squared_error: 0.0019 - accuracy: 0.0020
# Epoch 00136: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0320 - mean_squared_error: 0.0019 - accuracy: 0.0020 - val_loss: 0.0712 - val_mean_squared_error: 0.0088 - val_accuracy: 0.0019
# Epoch 137/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0321 - mean_squared_error: 0.0019 - accuracy: 0.0020
# Epoch 00137: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 206ms/step - loss: 0.0321 - mean_squared_error: 0.0019 - accuracy: 0.0020 - val_loss: 0.0695 - val_mean_squared_error: 0.0085 - val_accuracy: 0.0020
# Epoch 138/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0317 - mean_squared_error: 0.0019 - accuracy: 0.0020
# Epoch 00138: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 204ms/step - loss: 0.
val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0307 - mean_squared_error: 0.0017 - accuracy: 0.0020 - val_loss: 0.0732 - val_mean_squared_error: 0.0093 - val_accuracy: 0.0019
# Epoch 152/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0307 - mean_squared_error: 0.0018 - accuracy: 0.0020
# Epoch 00152: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0307 - mean_squared_error: 0.0018 - accuracy: 0.0020 - val_loss: 0.0673 - val_mean_squared_error: 0.0079 - val_accuracy: 0.0019
# Epoch 153/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0289 - mean_squared_error: 0.0016 - accuracy: 0.0020
# Epoch 00153: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0289 - mean_squared_error: 0.0016 - accuracy: 0.0020 - val_loss: 0.0709 - val_mean_squared_error: 0.0087 - val_accuracy: 0.0019
# Epoch 154/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0277 - mean_squared_error: 0.0014 - accuracy: 0.0020
# Epoch 00154: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0277 - mean_squared_error: 0.0014 - accuracy: 0.0020 - val_loss: 0.0708 - val_mean_squared_error: 0.0086 - val_accuracy: 0.0019
# Epoch 155/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0277 - mean_squared_error: 0.0014 - accuracy: 0.0020
# Epoch 00155: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0277 - mean_squared_error: 0.0014 - accuracy: 0.0020 - val_loss: 0.0669 - val_mean_squared_error: 0.0078 - val_accuracy: 0.0020
# Epoch 156/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0273 - mean_squared_error: 0.0014 - accuracy: 0.0020
# Epoch 00156: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0273 - mean_squared_error: 0.0014 - accuracy: 0.0020 - val_loss: 0.0702 - val_mean_squared_error: 0.0085 - val_accuracy: 0.0020
# Epoch 157/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0268 - mean_squared_error: 0.0013 - accuracy: 0.0020
# Epoch 00157: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 206ms/step - loss: 0.0268 - mean_squared_error: 0.0013 - accuracy: 0.0020 - val_loss: 0.0674 - val_mean_squared_error: 0.0079 - val_accuracy: 0.0020
# Epoch 158/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0276 - mean_squared_error: 0.0015 - accuracy: 0.0020
# Epoch 00158: val_loss did not improve from 0.06496
# 17/17 [==============================] - 4s 207ms/step - loss: 0.0276 - mean_squared_error: 0.0015 - accuracy: 0.0020 - val_loss: 0.0690 - val_mean_squared_error: 0.0084 - val_accuracy: 0.0019
# Epoch 159/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0291 - mean_squared_error: 0.0016 - accuracy: 0.0020
# Epoch 00159: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 205ms/step - loss: 0.0291 - mean_squared_error: 0.0016 - accuracy: 0.0020 - val_loss: 0.0702 - val_mean_squared_error: 0.0086 - val_accuracy: 0.0020
# Epoch 160/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0277 - mean_squared_error: 0.0014 - accuracy: 0.0020
# Epoch 00160: val_loss did not improve from 0.06496
# 17/17 [==============================] - 4s 210ms/step - loss: 0.0277 - mean_squared_error: 0.0014 - accuracy: 0.0020 - val_loss: 0.0709 - val_mean_squared_error: 0.0087 - val_accuracy: 0.0020
# Epoch 161/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0265 - mean_squared_error: 0.0013 - accuracy: 0.0020
# Epoch 00161: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 204ms/step - loss: 0.0265 - mean_squared_error: 0.0013 - accuracy: 0.0020 - val_loss: 0.0675 - val_mean_squared_error: 0.0078 - val_accuracy: 0.0020
# Epoch 162/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0266 - mean_squared_error: 0.0013 - accuracy: 0.0020
# Epoch 00162: val_loss did not improve from 0.06496
# 17/17 [==============================] - 4s 209ms/step - loss: 0.0266 - mean_squared_error: 0.0013 - accuracy: 0.0020 - val_loss: 0.0689 - val_mean_squared_error: 0.0082 - val_accuracy: 0.0020
# Epoch 163/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0263 - mean_squared_error: 0.0013 - accuracy: 0.0020
# Epoch 00163: val_loss did not improve from 0.06496
# 17/17 [==============================] - 3s 206ms/step - loss: 0.0263 - mean_squared_error: 0.0013 - accuracy: 0.0020 - val_loss: 0.0715 - val_mean_squared_error: 0.0091 - val_accuracy: 0.0019

# %% [markdown]
# # Prediction

# %%
if D_S == 0:
    GRF_pred = model.predict(X_Test, verbose=1)
    print(GRF_pred.shape)
elif D_S == 1:
    GRF_pred = model.predict(X_Test1, verbose=1)
    print(GRF_pred[0].shape)
# Out:
# 11/11 [==============================] - 2s 54ms/step
# (329, 1024, 1)

# %%
if D_S == 1:
    ground_truth_mean = np.mean(Y_Test, axis=0)
    ground_truth_std = np.std(Y_Test, axis=0)
    prediction = np.nan_to_num(GRF_pred[0][:, :, 0])
    prediction_mean = np.mean(prediction, axis=0)
    prediction_std = np.std(prediction, axis=0)

else:
    ground_truth_mean = np.mean(Y_Test, axis=0)
    ground_truth_std = np.std(Y_Test, axis=0)
    prediction = np.nan_to_num(GRF_pred[:, :, 0])
    prediction_mean = np.mean(prediction, axis=0)
    prediction_std = np.std(prediction, axis=0)

# %%
R = np.corrcoef(ground_truth_mean, prediction_mean)[0, 1]
R2 = pearsonr(ground_truth_mean, prediction_mean)[0]

# %%
plt.figure(figsize=(12, 7))
x = np.linspace(0, 100, FRAME_LEN)
plt.plot(x, ground_truth_mean, linewidth=3, label='Ground Truth')
plt.fill_between(
    x, ground_truth_mean + ground_truth_std,
    ground_truth_mean - ground_truth_std, alpha=0.3,
    label='Ground Truth +/- STD'
)
plt.plot(x, prediction_mean, linewidth=3, label='Prediction')
plt.fill_between(
    x, prediction_mean + prediction_std,
    prediction_mean - prediction_std, alpha=0.3,
    label='Prediction +/- STD'
)
plt.legend()
plt.title(f'R = {round(R, 5)}')
plt.xlabel('Stance Phase (%)')
plt.ylabel('Moment (Nm) (Normalized)')
# plt.savefig(figures_dir + 'Results_' + config + '.png')
plt.show()

# %% [markdown]
# # Save Model

# %%
# from shutil import copy
# copy('trained_models/' + config + '.h5', models_dir)
# joblib.dump(history, models_dir + \
#             'History_' + config + '.joblib')

# %% [markdown]
# # Learning curves

# %%
def history_plot(history):
    # list all dictionaries in history
    print(history.history.keys())
    # summarize history for error
    plt.figure(figsize=(11,7))
    plt.subplot(2,1,1)
    plt.plot(history.history['out_mean_squared_error'])
    plt.plot(history.history['val_out_mean_squared_error'])
    plt.title('Model Error Performance')
    plt.ylabel('Error')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper right')
    #   plt.ylim([0, 3])
    # plt.show()
    # summarize history for loss
    # plt.figure(figsize=(11,7))
    plt.subplot(2,1,2)
    plt.plot(history.history['out_loss'])
    plt.plot(history.history['val_out_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper right')
    #   plt.ylim([0, 3])
    # plt.savefig(figures_dir + 'LC_' + config + '.png')
    plt.show()
#
if D_S == 1:
    history_plot(history)

# %% [markdown]
# # Visualize outcomes

# %%
if D_S == 0:
    random_idx = random.sample(range(0, Y_Test.shape[0]), 6)
    plt.figure(figsize=(14, 9))
    for i in range(6):
        y_true = Y_Test[random_idx[i]]
        y_pred = GRF_pred[random_idx[i]]
        MAE = np.mean(np.abs(y_pred.ravel() - y_true.ravel()))
        plt.subplot(2, 3, i + 1)
        plt.plot(y_true, label='Ground Truth')
        plt.plot(y_pred.ravel(), label='Prediction')
        plt.title(f"MAE [{random_idx[i]}] : {MAE}")
        plt.legend();
    plt.show()
    
elif D_S == 1:
    random_idx = random.sample(range(0, Y_Test.shape[0]), 6)
    plt.figure(figsize=(14, 9))
    for i in range(6):
        y_true = Y_Test[random_idx[i]]
        y_pred = GRF_pred[0][random_idx[i]]
        MAE = np.mean(np.abs(y_pred.ravel() - y_true.ravel()))
        plt.subplot(2, 3, i + 1)
        plt.plot(y_true, label='Ground Truth', linewidth=3)
        plt.plot(y_pred.ravel(), label='Prediction', linewidth=3)
        plt.title(f"MAE [{random_idx[i]}] : {round(MAE, 4)}")
        plt.legend()
    # plt.savefig(figures_dir + 'Examples_' + config + '.png')
    plt.show()

# %% [markdown]
# # Construction Error

# %%
def Construction_Error(GRND, Pred):
    construction_err = []
    rmse = []
    corr_coef = []
    corr_coef2 = []
    bad_indices = []
    count = 0

    for i in range(len(GRND)):
        MAE = np.mean(np.abs(Pred[i].ravel() - GRND[i].ravel()))
        RMSE = mean_squared_error(np.nan_to_num(Pred[i].ravel()), GRND[i].ravel(), squared=False)
        R = np.corrcoef(np.nan_to_num(Pred[i].ravel()), GRND[i].ravel())[0, 1]
        R2 = pearsonr(np.nan_to_num(Pred[i].ravel()), GRND[i].ravel())[0]
        if MAE < 1:
            construction_err.append(MAE)
            rmse.append(RMSE)
            corr_coef.append(R)
            corr_coef2.append(R2)

        elif MAE >= 1:
            count = count + 1
            bad_indices.append(i)

    print(f'Construction Error : {round(np.mean(construction_err), 3)} +/- {round(np.std(construction_err), 3)}')
    print(f'RMSE : {round(np.mean(rmse), 3)} +/- {round(np.std(rmse), 3)}')
    print(f'R1 : {round(np.mean(corr_coef), 3)} +/- {round(np.std(corr_coef), 3)}')
    print(f'R2 : {round(np.mean(corr_coef2), 3)} +/- {round(np.std(corr_coef2), 3)}')
    print(f'Number of Bad Predictions = {count}')

    bad_indices = set(bad_indices)
    all_indices = set(np.arange(len(GRND)))
    good_indices = np.array(list(all_indices - bad_indices))
    GRND_NEW = GRND[good_indices]
    PRED_NEW = Pred[good_indices]

    return GRND_NEW, PRED_NEW

# %%
[A,B] = Construction_Error(Y_Test, GRF_pred)
# Out:
# Construction Error : 0.068 +/- 0.023
# RMSE : 0.087 +/- 0.029
# R1 : 0.952 +/- 0.039
# R2 : 0.952 +/- 0.039
# Number of Bad Predictions = 0

# %% [markdown]
# # Infinite loop to keep colab alive

# %%
# while True:
#     pass
